# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## pandas in Python
#
# * A powerful Python library for data analysis and manipulation.
# * Used to handle structured data like tables and spreadsheets.
# * Provides two main data structures: **Series** and **DataFrame**.
# * Helps in cleaning, filtering, sorting, and analyzing data easily.
# * Widely used in Data Analytics, Machine Learning, and Data Science.

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"D:\OneDrive\data science\pandas\Used_Bikes.csv")

# %%
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df.head()#by default 1st five rows pass krta h
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
df.head(10)#if we pass a value to utni rows deta h
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# 5                          Yamaha FZs 150cc   53499.0      Delhi     25000.0
# 6             Honda CB Hornet 160R  ABS DLX   85000.0      Delhi      8200.0
# 7       Hero Splendor Plus Self Alloy 100cc   45000.0      Delhi     12645.0
# 8         Royal Enfield Thunderbird X 350cc  145000.0  Bangalore      9190.0
# 9  Royal Enfield Classic Desert Storm 500cc   88000.0      Delhi     19000.0
#
#           owner  age  power          brand
# 0   First Owner  3.0  110.0            TVS
# ...

# %%
df.tail()#by default last five rows deta h and if we pass a value to last utni rows deta h
# Out:
#                        bike_name    price    city  kms_driven        owner  \
# 32643     Hero Passion Pro 100cc  39000.0   Delhi     22000.0  First Owner
# 32644       TVS Apache RTR 180cc  30000.0  Karnal      6639.0  First Owner
# 32645   Bajaj Avenger Street 220  60000.0   Delhi     20373.0  First Owner
# 32646  Hero Super Splendor 125cc  15600.0  Jaipur     84186.0  First Owner
# 32647         Bajaj Pulsar 150cc  22000.0    Pune     60857.0  First Owner
#
#         age  power  brand
# 32643   4.0  100.0   Hero
# 32644   9.0  180.0    TVS
# 32645   6.0  220.0  Bajaj
# 32646  16.0  125.0   Hero
# 32647  13.0  150.0  Bajaj

# %%
df.info()# gives information about dataset
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 32648 entries, 0 to 32647
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bike_name   32648 non-null  str
#  1   price       32648 non-null  float64
#  2   city        32648 non-null  str
#  3   kms_driven  32648 non-null  float64
#  4   owner       32648 non-null  str
#  5   age         32648 non-null  float64
#  6   power       32648 non-null  float64
#  7   brand       32648 non-null  str
# dtypes: float64(4), str(4)
# memory usage: 2.0 MB

# %%
df.columns# gives all the columns
# Out:
# Index(['bike_name', 'price', 'city', 'kms_driven', 'owner', 'age', 'power',
#        'brand'],
#       dtype='str')

# %%
df["price"]#specific column
# Out:
# 0         35000.0
# 1        119900.0
# 2        600000.0
# 3         65000.0
# 4         80000.0
#            ...
# 32643     39000.0
# 32644     30000.0
# 32645     60000.0
# 32646     15600.0
# 32647     22000.0
# Name: price, Length: 32648, dtype: float64

# %%
df[["brand"]]#more sturctured
# Out:
#                brand
# 0                TVS
# 1      Royal Enfield
# 2            Triumph
# 3                TVS
# 4             Yamaha
# ...              ...
# 32643           Hero
# 32644            TVS
# 32645          Bajaj
# 32646           Hero
# 32647          Bajaj
#
# [32648 rows x 1 columns]

# %%
df[['brand','price']]
# Out:
#                brand     price
# 0                TVS   35000.0
# 1      Royal Enfield  119900.0
# 2            Triumph  600000.0
# 3                TVS   65000.0
# 4             Yamaha   80000.0
# ...              ...       ...
# 32643           Hero   39000.0
# 32644            TVS   30000.0
# 32645          Bajaj   60000.0
# 32646           Hero   15600.0
# 32647          Bajaj   22000.0
#
# [32648 rows x 2 columns]

# %%
df["brand"].unique()#kon konsi brand h
# Out:
# <StringArray>
# [            'TVS',   'Royal Enfield',         'Triumph',          'Yamaha',
#            'Honda',            'Hero',           'Bajaj',          'Suzuki',
#          'Benelli',             'KTM',        'Mahindra',        'Kawasaki',
#           'Ducati',         'Hyosung', 'Harley-Davidson',            'Jawa',
#              'BMW',          'Indian',         'Rajdoot',             'LML',
#            'Yezdi',              'MV',           'Ideal']
# Length: 23, dtype: str

# %%
df["owner"].unique()
# Out:
# <StringArray>
# ['First Owner', 'Second Owner', 'Third Owner', 'Fourth Owner Or More']
# Length: 4, dtype: str

# %%
df["brand"].nunique()#no. of unique brands
# Out:
# 23

# %%
df['brand'].value_counts()#har brand m kitni bikes h
# Out:
# brand
# Bajaj              11213
# Hero                6368
# Royal Enfield       4178
# Yamaha              3916
# Honda               2108
# Suzuki              1464
# TVS                 1247
# KTM                 1077
# Harley-Davidson      737
# Kawasaki              79
# Hyosung               64
# Benelli               56
# Mahindra              55
# Triumph               26
# Ducati                22
# BMW                   16
# Jawa                  10
# MV                     4
# Indian                 3
# Ideal                  2
# Rajdoot                1
# LML                    1
# Yezdi                  1
# Name: count, dtype: int64

# %%
#

# %%
df.duplicated()#duplicate values p true dega
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32643     True
# 32644     True
# 32645     True
# 32646     True
# 32647     True
# Length: 32648, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(25324)

# %%
df.drop_duplicates()#duplicate values ko drop kr dega
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...

# %%
df.drop_duplicates(inplace=True)#duplicate values ko drop kr dega

# %%
df
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...

# %%
df.isna()#missing values p true dega
# Out:
#       bike_name  price   city  kms_driven  owner    age  power  brand
# 0         False  False  False       False  False  False  False  False
# 1         False  False  False       False  False  False  False  False
# 2         False  False  False       False  False  False  False  False
# 3         False  False  False       False  False  False  False  False
# 4         False  False  False       False  False  False  False  False
# ...         ...    ...    ...         ...    ...    ...    ...    ...
# 9362      False  False  False       False  False  False  False  False
# 9369      False  False  False       False  False  False  False  False
# 9370      False  False  False       False  False  False  False  False
# 9371      False  False  False       False  False  False  False  False
# 9372      False  False  False       False  False  False  False  False
#
# [7324 rows x 8 columns]

# %%
df.isnull().sum()#null values p true dega
# Out:
# bike_name     0
# price         0
# city          0
# kms_driven    0
# owner         0
# age           0
# power         0
# brand         0
# dtype: int64

# %%
df.dropna(inplace=True)#missing values ko drop kr dega

# %%
#1st algo of ML
#linear equation 
#y = mx+c
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 7324 entries, 0 to 9372
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bike_name   7324 non-null   str
#  1   price       7324 non-null   float64
#  2   city        7324 non-null   str
#  3   kms_driven  7324 non-null   float64
#  4   owner       7324 non-null   str
#  5   age         7324 non-null   float64
#  6   power       7324 non-null   float64
#  7   brand       7324 non-null   str
# dtypes: float64(4), str(4)
# memory usage: 515.0 KB

# %%
df['owner'].unique()
# Out:
# <StringArray>
# ['First Owner', 'Second Owner', 'Third Owner', 'Fourth Owner Or More']
# Length: 4, dtype: str

# %%
owner_dict = {'First Owner': 1,'Second Owner': 2,'Third Owner': 3,'Fourth & Above Owner': 4}

# %%
df['owner']=df['owner'].map(owner_dict)

# %%
df
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#       owner  age  power            brand
# ...

# %%
#df.drop('city',axis=1,inplace=True)#city column ko drop kr diya

# %%
#df.drop(['city','bike_name'],axis=1,inplace=True)#city column ko drop kr diya

# %%
tvs_brand=df[df['brand']=='TVS']#

# %%
df
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#       owner  age  power            brand
# ...

# %%
tvs_under2 = tvs_brand[tvs_brand['age']<=2]

# %%
tvs_under2[tvs_under2['kms_driven']<=20000]
# Out:
#                                               bike_name     price       city  \
# 193                  TVS Apache RTR 160 4V DISC ABS BS6   85000.0  Hyderabad
# 360                          TVS Apache RTR 160 4V Disc   78700.0   Rudrapur
# 401              TVS Apache RTR 200 4V ABS Race Edition  108500.0      Delhi
# 425                      TVS Apache RTR 160 4V DISC ABS   87000.0      Delhi
# 511                      TVS Apache RTR 160 4V DRUM ABS   85000.0    Gurgaon
# 594                      TVS Apache RTR 160 4V DISC ABS   91800.0      Delhi
# 664                      TVS Apache RTR 160 4V DISC ABS   89000.0      Delhi
# 1097  TVS Apache RTR 200 4V Carburetor Race Edition 2.0   93500.0  Bangalore
# 1126         TVS Apache RTR 200 4V Dual Channel ABS BS6  130000.0  Bangalore
# 1132                 TVS Apache RTR 160 4V DISC ABS BS6   98000.0     Jaipur
# 1171                                   TVS Apache RR310  200000.0     Mumbai
# ...

# %%
royal_brand=df[df['brand']=='Royal Enfield']

# %%
ROYAL_under2 = royal_brand[royal_brand['age']<=2]

# %%
df[(df['brand']=='Royal Enfield') & (df['age']<=2) & (df['price']<=150000)] #multiple conditions
# Out:
#                                              bike_name     price       city  \
# 194                        Royal Enfield Electra 350cc  145000.0  Bangalore
# 479                        Royal Enfield Classic 350cc  150000.0      Delhi
# 1006               Royal Enfield Thunderbird 350cc ABS  148000.0   Haldwani
# 1203     Royal Enfield Classic Gunmetal Grey 350cc ABS  150000.0  Bardhaman
# 1681             Royal Enfield Thunderbird X 350cc ABS  135000.0   Sibsagar
# 1716               Royal Enfield Thunderbird 350cc ABS  144700.0     Kharar
# 1749    Royal Enfield Bullet Twinspark Kickstart 350cc  145000.0      Delhi
# 2982      Royal Enfield Classic 350cc-Redditch Edition  137000.0  Sultanpur
# 5495                       Royal Enfield Classic 350cc  150000.0       Kota
# 5939    Royal Enfield Bullet Twinspark Kickstart 350cc  105000.0  Faridabad
# 6090  Royal Enfield Bullet Electra Twinspark 350CC ABS  127000.0     Mumbai
# ...

# %%
df.query("brand=='Royal Enfield' and age<=2" )#same query in different way
# Out:
#                                          bike_name     price          city  \
# 38               Royal Enfield Thunderbird X 500cc  190500.0    Samastipur
# 81                 Royal Enfield Interceptor 650cc  260000.0   Navi Mumbai
# 139           Royal Enfield Himalayan 410cc Fi ABS  173300.0      Vadodara
# 194                    Royal Enfield Electra 350cc  145000.0     Bangalore
# 222           Royal Enfield Himalayan 410cc Fi ABS  177982.0  Hamirpur(hp)
# ...                                            ...       ...           ...
# 7294  Royal Enfield Classic 350cc-Redditch Edition  133500.0        Mumbai
# 7694        Royal Enfield Classic Chrome 500cc ABS  215000.0         Delhi
# 8139         Royal Enfield Thunderbird X 350cc ABS  169000.0     Bangalore
# 8192           Royal Enfield Thunderbird 350cc ABS  145000.0     Ghaziabad
# 8836         Royal Enfield Thunderbird X 350cc ABS  170200.0        Mumbai
#
#       kms_driven  owner  age  power          brand
# ...

# %%
df.drop(['bike_name'],axis=1,inplace=True)#drop column

# %%
x=df.drop(['price'],axis=1)#drop column

# %%
y=df['price']#target variable

# %%
y
# Out:
# 0        35000.0
# 1       119900.0
# 2       600000.0
# 3        65000.0
# 4        80000.0
#           ...
# 9362     25000.0
# 9369     35000.0
# 9370    450000.0
# 9371    139000.0
# 9372     80000.0
# Name: price, Length: 7324, dtype: float64

# %%
x
# Out:
#            city  kms_driven  owner  age  power            brand
# 0     Ahmedabad     17654.0    1.0  3.0  110.0              TVS
# 1         Delhi     11000.0    1.0  4.0  350.0    Royal Enfield
# 2         Delhi       110.0    1.0  8.0  675.0          Triumph
# 3     Bangalore     16329.0    1.0  4.0  180.0              TVS
# 4     Bangalore     10000.0    1.0  3.0  150.0           Yamaha
# ...         ...         ...    ...  ...    ...              ...
# 9362      Delhi     48587.0    1.0  8.0  150.0             Hero
# 9369  Bangalore     60000.0    1.0  9.0  220.0            Bajaj
# 9370    Jodhpur      3430.0    1.0  4.0  750.0  Harley-Davidson
# 9371  Hyderabad     21300.0    1.0  4.0  400.0            Bajaj
# 9372  Hyderabad      7127.0    1.0  5.0  220.0            Bajaj
#
# [7324 rows x 6 columns]

# %%
df
# Out:
#          price       city  kms_driven  owner  age  power            brand
# 0      35000.0  Ahmedabad     17654.0    1.0  3.0  110.0              TVS
# 1     119900.0      Delhi     11000.0    1.0  4.0  350.0    Royal Enfield
# 2     600000.0      Delhi       110.0    1.0  8.0  675.0          Triumph
# 3      65000.0  Bangalore     16329.0    1.0  4.0  180.0              TVS
# 4      80000.0  Bangalore     10000.0    1.0  3.0  150.0           Yamaha
# ...        ...        ...         ...    ...  ...    ...              ...
# 9362   25000.0      Delhi     48587.0    1.0  8.0  150.0             Hero
# 9369   35000.0  Bangalore     60000.0    1.0  9.0  220.0            Bajaj
# 9370  450000.0    Jodhpur      3430.0    1.0  4.0  750.0  Harley-Davidson
# 9371  139000.0  Hyderabad     21300.0    1.0  4.0  400.0            Bajaj
# 9372   80000.0  Hyderabad      7127.0    1.0  5.0  220.0            Bajaj
#
# [7324 rows x 7 columns]

# %%
df.columns
# Out:
# Index(['price', 'city', 'kms_driven', 'owner', 'age', 'power', 'brand'], dtype='str')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.histplot(df['price'], kde=True)

plt.title('Distribution of Bike Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
sns.scatterplot(x='kms_driven',y='price',data=df)
plt.title('Price vs Kilometers Driven')
plt.xlabel('Kilometers Driven')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
sns.barplot(x='owner',y='price',data=df,errorbar= None)
plt.title('Average Price by Owner Type')
plt.xlabel('Owner Type')
plt.ylabel('Average Price')
# Out:
# Text(0, 0.5, 'Average Price')

# %%
sns.scatterplot(x='age',y='price',data=df)
plt.title('Price vs Bike Age')
plt.xlabel('Bike Age (Years)')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
sns.scatterplot(x='power',y='price',data=df)
plt.title('Price vs Engine Power')
plt.xlabel('Engine Power (cc)')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
brand_price = (df.groupby('brand')['price'].mean().sort_values())
brand_price.plot(kind='barh')
plt.title('Average Bike Price by Brand')
plt.xlabel('Average Price')
plt.ylabel('Brand')
# Out:
# Text(0, 0.5, 'Brand')

# %%
num_cols = ['price','kms_driven','age','power']
sns.heatmap(df[num_cols].corr(),annot=True,cmap='coolwarm')
plt.title('Correlation Heatmap')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
owner_dict ={
    'First Owner':1, 'Second Owner':2, 'Third Owner':3, 'Fourth Owner Or More':4
}
df['owner']=df['owner'].map(owner_dict)##map function used for mapping

# %%
df["brand"].unique()
brand_dict={   'TVS':1,   'Royal Enfield':2,         'Triumph':3,          'Yamaha':4,
           'Honda':5,            'Hero':6,           'Bajaj':7,          'Suzuki':8,
         'Benelli':9,             'KTM':10,        'Mahindra':11,        'Kawasaki':12,
          'Ducati':13,         'Hyosung':14, 'Harley-Davidson':15,            'Jawa':16,
             'BMW':17,          'Indian':18,         'Rajdoot':19,             'LML':20,
           'Yezdi':21,              'MV':22,           'Ideal':23}

df['brand']=df['brand'].map(brand_dict)

# %%
city_dict={ 'Ahmedabad':1,        'Delhi':2,    'Bangalore':3,       'Mumbai':4,
       'Kalyan':5,    'Faridabad':6,       'Mettur':6,    'Hyderabad':7,
      'Kaithal':8,      'Gurgaon':9,
 
  'Bhubaneswar':10,      'Raiganj':11, 'Bhilai Nagar':12,       'Baloda':13,
     'Anantnag':14,   'Berhampore':15,      'Silvasa':16,       'Hospet':17,
        'Palai':18,        'Sidhi':19}

df['city']=df['city'].map(city_dict)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 7324 entries, 0 to 9372
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   price       7324 non-null   float64
#  1   city        4165 non-null   float64
#  2   kms_driven  7324 non-null   float64
#  3   owner       0 non-null      float64
#  4   age         7324 non-null   float64
#  5   power       7324 non-null   float64
#  6   brand       7324 non-null   int64
# dtypes: float64(6), int64(1)
# memory usage: 457.8 KB

# %%
df.to_csv("clean_bike_data.csv")

# %%
df.duplicated().sum()
# Out:
# np.int64(11)

# %%
df.isna().sum()
# Out:
# price            0
# city          3159
# kms_driven       0
# owner         7324
# age              0
# power            0
# brand            0
# dtype: int64
